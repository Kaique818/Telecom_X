# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaique818/Telecom_X/blob/main/TelecomX_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracão

# %%
import pandas as pd

# %%
dados_telecom = pd.read_json('/content/TelecomX_Data.json')
dados_telecom
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %% [markdown]
# #🔧 Transformação

# %%
# É tipo objeto
dados_telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
#verificando TIPOS DE DADOS incorretos
dados_telecom.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
#Verificando possíveis valores estranhos
for col in dados_telecom.columns:
    print(f"\n--- Coluna: {col} ---")
    try:
        print(dados_telecom[col].unique()[:20])  # Limita a 20 valores
    except Exception:
        print("Contém valores não exibíveis (dict, list ou estruturas complexas).")
        print("Tipos encontrados:", dados_telecom[col].apply(type).unique())
# Out:
# --- Coluna: customerID ---
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' '0011-IGKFF' '0013-EXCHZ'
#  '0013-MHZWF' '0013-SMEOE' '0014-BMAQU' '0015-UOCOJ' '0016-QLJIS'
#  '0017-DINOC' '0017-IUDMW' '0018-NYROU' '0019-EFAEP' '0019-GFNTW'
#  '0020-INWCK' '0020-JDNXP' '0021-IKXGC' '0022-TCJCI' '0023-HGHWL']
#
# --- Coluna: Churn ---
# ['No' 'Yes' '']
#
# --- Coluna: customer ---
# Contém valores não exibíveis (dict, list ou estruturas complexas).
# Tipos encontrados: [<class 'dict'>]
#
# --- Coluna: phone ---
# Contém valores não exibíveis (dict, list ou estruturas complexas).
# Tipos encontrados: [<class 'dict'>]
#
# --- Coluna: internet ---
# Contém valores não exibíveis (dict, list ou estruturas complexas).
# Tipos encontrados: [<class 'dict'>]
#
# --- Coluna: account ---
# Contém valores não exibíveis (dict, list ou estruturas complexas).
# Tipos encontrados: [<class 'dict'>]

# %%
#Verificando se EXISTEM VALORES NULOS (NA)
dados_telecom.isna().sum().sort_values(ascending=False)
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
#Verificando se existem DUPLICATAS
dados_telecom.duplicated(subset='customerID').sum()
# Out:
# np.int64(0)

# %%
#Verificando STRINGS vazias, espaços e caracteres problemáticos
print("Strings vazias:")
print((dados_telecom == '').sum().sort_values(ascending=False))

print("\nEspaços em branco:")
print((dados_telecom == ' ').sum().sort_values(ascending=False))

print("\nInterrogações como valores:")
print((dados_telecom == '?').sum().sort_values(ascending=False))
# Out:
# Strings vazias:
# Churn         224
# customerID      0
# customer        0
# phone           0
# internet        0
# account         0
# dtype: int64
#
# Espaços em branco:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64
#
# Interrogações como valores:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
#Verificando se colunas numéricas têm valores inválidos
dados_telecom.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
for col in ['customerID', 'Churn', 'customer_gender', 'customer_SeniorCitizen',
       'customer_Partner', 'customer_Dependents', 'customer_tenure',
       'phone_PhoneService', 'phone_MultipleLines', 'internet_InternetService',
       'internet_OnlineSecurity', 'internet_OnlineBackup',
       'internet_DeviceProtection', 'internet_TechSupport',
       'internet_StreamingTV', 'internet_StreamingMovies', 'account_Contract',
       'account_PaperlessBilling', 'account_PaymentMethod',
       'account_Charges.Monthly', 'account_Charges.Total',
       'account_Charges.Monthly_num', 'account_Charges.Total_num',
       'customer_tenure_num']:  # substitua pelos nomes corretos
    if col in dados_telecom.columns:
        print(f"\nTestando: {col}")
        print(pd.to_numeric(dados_telecom[col], errors='coerce').isna().sum())
# Out:
# Testando: customerID
# 7267
#
# Testando: Churn
# 7267

# %% [markdown]
# #Lista de inconsistências
#
# A maioria dos dados aparecem como object e int64, aparecem muitos Yes / no, valores 0, duplicatas são np.int64(0), as strings são zero, As colunas possuem valores diferentes como 0 ,7267 e 11.

# %%
#TRATANDO
df = dados_telecom.copy()

# %%
#Remover registros com Churn vazio
df = df[df['Churn'] != '']

# %%
#Converter Churn para valores binários (0/1)
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.columns.tolist()
# Out:
# ['customerID', 'Churn', 'customer', 'phone', 'internet', 'account']

# %%
import pandas as pd

df = dados_telecom.copy()

# Identificar colunas que têm dicionários internos
dict_cols = [c for c in df.columns if df[c].apply(lambda x: isinstance(x, dict)).any()]

# Expandir cada coluna-dicionário
for col in dict_cols:
    expanded = pd.json_normalize(df[col])
    expanded.columns = [f"{col}_{subcol}" for subcol in expanded.columns]
    df = pd.concat([df.drop(columns=[col]), expanded], axis=1)

df.head()
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer_Dependents  customer_tenure phone_PhoneService phone_MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
#   internet_InternetService  ... internet_OnlineBackup  \
# 0                      DSL  ...                   Yes
# 1                      DSL  ...                    No
# 2              Fiber optic  ...                    No
# 3              Fiber optic  ...                   Yes
# 4              Fiber optic  ...                    No
#
#   internet_DeviceProtection internet_TechSupport internet_StreamingTV  \
# 0                        No                  Yes                  Yes
# 1                        No                   No                   No
# 2                       Yes                   No                   No
# 3                       Yes                   No                  Yes
# 4                        No                  Yes                  Yes
#
#   internet_StreamingMovies account_Contract account_PaperlessBilling  \
# 0                       No         One year                      Yes
# 1                      Yes   Month-to-month                       No
# 2                       No   Month-to-month                      Yes
# 3                      Yes   Month-to-month                      Yes
# 4                       No   Month-to-month                      Yes
#
#   account_PaymentMethod account_Charges.Monthly  account_Charges.Total
# 0          Mailed check                    65.6                  593.3
# 1          Mailed check                    59.9                  542.4
# 2      Electronic check                    73.9                 280.85
# 3      Electronic check                    98.0                1237.85
# 4          Mailed check                    83.9                  267.4
#
# [5 rows x 21 columns]

# %%
#Padronizar colunas Yes/No
df = df.replace({
    'No internet service': 'No',
    'No phone service': 'No'
})

yes_no_cols = [
    'customer_Partner', 'customer_Dependents',
    'phone_PhoneService', 'phone_MultipleLines',
    'internet_OnlineSecurity', 'internet_OnlineBackup',
    'internet_DeviceProtection', 'internet_TechSupport',
    'internet_StreamingTV', 'internet_StreamingMovies',
    'account_PaperlessBilling'
]

for col in yes_no_cols:
    df[col] = df[col].map({'Yes': 1, 'No': 0})

# %%
#Corrigir colunas numéricas

df['account_Charges.Monthly'] = pd.to_numeric(df['account_Charges.Monthly'], errors='coerce')
df['account_Charges.Total'] = pd.to_numeric(df['account_Charges.Total'], errors='coerce')
df['customer_tenure'] = pd.to_numeric(df['customer_tenure'], errors='coerce')

df = df.drop(columns=[col for col in df.columns if col.endswith('_num')])

# %%
#Tratando valores muito estranhos
cols_object = df.select_dtypes(include='object').columns

for col in cols_object:
    df[col] = df[col].astype(str).str.strip()

# %%
#Remover duplicatas
df.drop_duplicates(subset='customerID', inplace=True)

# %%
#Resetando índice
df.reset_index(drop=True, inplace=True)

# %%
#Vendo o resultado final
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   int64
#  5   customer_Dependents        7267 non-null   int64
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   int64
#  8   phone_MultipleLines        7267 non-null   int64
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   int64
#  11  internet_OnlineBackup      7267 non-null   int64
#  12  internet_DeviceProtection  7267 non-null   int64
#  13  internet_TechSupport       7267 non-null   int64
#  14  internet_StreamingTV       7267 non-null   int64
#  15  internet_StreamingMovies   7267 non-null   int64
#  16  account_Contract           7267 non-null   object
#  17  account_PaperlessBilling   7267 non-null   int64
#  18  account_PaymentMethod      7267 non-null   object
#  19  account_Charges.Monthly    7267 non-null   float64
#  20  account_Charges.Total      7256 non-null   float64
# dtypes: float64(2), int64(13), object(6)
# memory usage: 1.2+ MB
#    customerID Churn customer_gender  customer_SeniorCitizen  customer_Partner  \
# 0  0002-ORFBO    No          Female                       0                 1
# 1  0003-MKNFE    No            Male                       0                 0
# 2  0004-TLHLJ   Yes            Male                       0                 0
# 3  0011-IGKFF   Yes            Male                       1                 1
# 4  0013-EXCHZ   Yes          Female                       1                 1
#
#    customer_Dependents  customer_tenure  phone_PhoneService  \
# 0                    1                9                   1
# 1                    0                9                   1
# 2                    0                4                   1
# 3                    0               13                   1
# 4                    0                3                   1
#
#    phone_MultipleLines internet_InternetService  ...  internet_OnlineBackup  \
# 0                    0                      DSL  ...                      1
# 1                    1                      DSL  ...                      0
# 2                    0              Fiber optic  ...                      0
# 3                    0              Fiber optic  ...                      1
# 4                    0              Fiber optic  ...                      0
#
#    internet_DeviceProtection  internet_TechSupport  internet_StreamingTV  \
# 0                          0                     1                     1
# 1                          0                     0                     0
# 2                          1                     0                     0
# 3                          1                     0                     1
# 4                          0                     1                     1
#
#    internet_StreamingMovies  account_Contract account_PaperlessBilling  \
# 0                         0          One year                        1
# 1                         1    Month-to-month                        0
# 2                         0    Month-to-month                        1
# 3                         1    Month-to-month                        1
# 4                         0    Month-to-month                        1
#
#    account_PaymentMethod account_Charges.Monthly  account_Charges.Total
# 0           Mailed check                    65.6                 593.30
# 1           Mailed check                    59.9                 542.40
# 2       Electronic check                    73.9                 280.85
# 3       Electronic check                    98.0                1237.85
# 4           Mailed check                    83.9                 267.40
#
# [5 rows x 21 columns]

# %%
#Criando a coluna dados_mensais (extra)

# Criar coluna de cobrança diária
df['Contas_Diarias'] = df['account_Charges.Monthly'] / 30

# Visualizar resultado
df[['account_Charges.Monthly', 'Contas_Diarias']].head()
# Out:
#    account_Charges.Monthly  Contas_Diarias
# 0                     65.6        2.186667
# 1                     59.9        1.996667
# 2                     73.9        2.463333
# 3                     98.0        3.266667
# 4                     83.9        2.796667

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'Churn',
#  'customer_gender',
#  'customer_SeniorCitizen',
#  'customer_Partner',
#  'customer_Dependents',
#  'customer_tenure',
#  'phone_PhoneService',
#  'phone_MultipleLines',
#  'internet_InternetService',
#  'internet_OnlineSecurity',
#  'internet_OnlineBackup',
#  'internet_DeviceProtection',
#  'internet_TechSupport',
#  'internet_StreamingTV',
#  'internet_StreamingMovies',
#  'account_Contract',
#  'account_PaperlessBilling',
#  'account_PaymentMethod',
#  'account_Charges.Monthly',
#  'account_Charges.Total',
#  'Contas_Diarias']

# %%
df['Contas_Diarias'] = df['account_Charges.Monthly'] / 30

# %% [markdown]
# #📊 Carga e análise

# %%
df.describe()
# Out:
#        customer_SeniorCitizen  customer_Partner  customer_Dependents  \
# count             7267.000000       7267.000000          7267.000000
# mean                 0.162653          0.484106             0.300124
# std                  0.369074          0.499782             0.458343
# min                  0.000000          0.000000             0.000000
# 25%                  0.000000          0.000000             0.000000
# 50%                  0.000000          0.000000             0.000000
# 75%                  0.000000          1.000000             1.000000
# max                  1.000000          1.000000             1.000000
#
#        customer_tenure  phone_PhoneService  phone_MultipleLines  \
# count      7267.000000         7267.000000          7267.000000
# mean         32.346498            0.902711             0.421770
# std          24.571773            0.296371             0.493876
# min           0.000000            0.000000             0.000000
# 25%           9.000000            1.000000             0.000000
# 50%          29.000000            1.000000             0.000000
# 75%          55.000000            1.000000             1.000000
# max          72.000000            1.000000             1.000000
#
#        internet_OnlineSecurity  internet_OnlineBackup  \
# count              7267.000000            7267.000000
# mean                  0.285950               0.344571
# std                   0.451897               0.475261
# min                   0.000000               0.000000
# 25%                   0.000000               0.000000
# 50%                   0.000000               0.000000
# 75%                   1.000000               1.000000
# max                   1.000000               1.000000
#
#        internet_DeviceProtection  internet_TechSupport  internet_StreamingTV  \
# count                7267.000000           7267.000000           7267.000000
# mean                    0.342782              0.289528              0.383927
# std                     0.474672              0.453575              0.486374
# min                     0.000000              0.000000              0.000000
# 25%                     0.000000              0.000000              0.000000
# 50%                     0.000000              0.000000              0.000000
# 75%                     1.000000              1.000000              1.000000
# max                     1.000000              1.000000              1.000000
#
#        internet_StreamingMovies  account_PaperlessBilling  \
# count               7267.000000               7267.000000
# mean                   0.387505                  0.593230
# std                    0.487214                  0.491265
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  1.000000
# 75%                    1.000000                  1.000000
# max                    1.000000                  1.000000
#
#        account_Charges.Monthly  account_Charges.Total  Contas_Diarias
# count              7267.000000            7256.000000     7267.000000
# mean                 64.720098            2280.634213        2.157337
# std                  30.129572            2268.632997        1.004319
# min                  18.250000              18.800000        0.608333
# 25%                  35.425000             400.225000        1.180833
# 50%                  70.300000            1391.000000        2.343333
# 75%                  89.875000            3785.300000        2.995833
# max                 118.750000            8684.800000        3.958333

# %%
df.describe(include='all')
# Out:
#         customerID Churn customer_gender  customer_SeniorCitizen  \
# count         7267  7267            7267             7267.000000
# unique        7267     3               2                     NaN
# top     9995-HOTOH    No            Male                     NaN
# freq             1  5174            3675                     NaN
# mean           NaN   NaN             NaN                0.162653
# std            NaN   NaN             NaN                0.369074
# min            NaN   NaN             NaN                0.000000
# 25%            NaN   NaN             NaN                0.000000
# 50%            NaN   NaN             NaN                0.000000
# 75%            NaN   NaN             NaN                0.000000
# max            NaN   NaN             NaN                1.000000
#
#         customer_Partner  customer_Dependents  customer_tenure  \
# count        7267.000000          7267.000000      7267.000000
# unique               NaN                  NaN              NaN
# top                  NaN                  NaN              NaN
# freq                 NaN                  NaN              NaN
# mean            0.484106             0.300124        32.346498
# std             0.499782             0.458343        24.571773
# min             0.000000             0.000000         0.000000
# 25%             0.000000             0.000000         9.000000
# 50%             0.000000             0.000000        29.000000
# 75%             1.000000             1.000000        55.000000
# max             1.000000             1.000000        72.000000
#
#         phone_PhoneService  phone_MultipleLines internet_InternetService  ...  \
# count          7267.000000          7267.000000                     7267  ...
# unique                 NaN                  NaN                        3  ...
# top                    NaN                  NaN              Fiber optic  ...
# freq                   NaN                  NaN                     3198  ...
# mean              0.902711             0.421770                      NaN  ...
# std               0.296371             0.493876                      NaN  ...
# min               0.000000             0.000000                      NaN  ...
# 25%               1.000000             0.000000                      NaN  ...
# 50%               1.000000             0.000000                      NaN  ...
# 75%               1.000000             1.000000                      NaN  ...
# max               1.000000             1.000000                      NaN  ...
#
#         internet_DeviceProtection  internet_TechSupport  internet_StreamingTV  \
# count                 7267.000000           7267.000000           7267.000000
# unique                        NaN                   NaN                   NaN
# top                           NaN                   NaN                   NaN
# freq                          NaN                   NaN                   NaN
# mean                     0.342782              0.289528              0.383927
# std                      0.474672              0.453575              0.486374
# min                      0.000000              0.000000              0.000000
# 25%                      0.000000              0.000000              0.000000
# 50%                      0.000000              0.000000              0.000000
# 75%                      1.000000              1.000000              1.000000
# max                      1.000000              1.000000              1.000000
#
#         internet_StreamingMovies  account_Contract  account_PaperlessBilling  \
# count                7267.000000              7267               7267.000000
# unique                       NaN                 3                       NaN
# top                          NaN    Month-to-month                       NaN
# freq                         NaN              4005                       NaN
# mean                    0.387505               NaN                  0.593230
# std                     0.487214               NaN                  0.491265
# min                     0.000000               NaN                  0.000000
# 25%                     0.000000               NaN                  0.000000
# 50%                     0.000000               NaN                  1.000000
# 75%                     1.000000               NaN                  1.000000
# max                     1.000000               NaN                  1.000000
#
#        account_PaymentMethod  account_Charges.Monthly account_Charges.Total  \
# count                   7267              7267.000000           7256.000000
# unique                     4                      NaN                   NaN
# top         Electronic check                      NaN                   NaN
# freq                    2445                      NaN                   NaN
# mean                     NaN                64.720098           2280.634213
# std                      NaN                30.129572           2268.632997
# min                      NaN                18.250000             18.800000
# 25%                      NaN                35.425000            400.225000
# 50%                      NaN                70.300000           1391.000000
# 75%                      NaN                89.875000           3785.300000
# max                      NaN               118.750000           8684.800000
#
#         Contas_Diarias
# count      7267.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean          2.157337
# std           1.004319
# min           0.608333
# 25%           1.180833
# 50%           2.343333
# 75%           2.995833
# max           3.958333
#
# [11 rows x 22 columns]

# %%
#Média
df.mean(numeric_only=True)
# Out:
# customer_SeniorCitizen          0.162653
# customer_Partner                0.484106
# customer_Dependents             0.300124
# customer_tenure                32.346498
# phone_PhoneService              0.902711
# phone_MultipleLines             0.421770
# internet_OnlineSecurity         0.285950
# internet_OnlineBackup           0.344571
# internet_DeviceProtection       0.342782
# internet_TechSupport            0.289528
# internet_StreamingTV            0.383927
# internet_StreamingMovies        0.387505
# account_PaperlessBilling        0.593230
# account_Charges.Monthly        64.720098
# account_Charges.Total        2280.634213
# Contas_Diarias                  2.157337
# dtype: float64

# %%
#Mediana
df.median(numeric_only=True)
# Out:
# customer_SeniorCitizen          0.000000
# customer_Partner                0.000000
# customer_Dependents             0.000000
# customer_tenure                29.000000
# phone_PhoneService              1.000000
# phone_MultipleLines             0.000000
# internet_OnlineSecurity         0.000000
# internet_OnlineBackup           0.000000
# internet_DeviceProtection       0.000000
# internet_TechSupport            0.000000
# internet_StreamingTV            0.000000
# internet_StreamingMovies        0.000000
# account_PaperlessBilling        1.000000
# account_Charges.Monthly        70.300000
# account_Charges.Total        1391.000000
# Contas_Diarias                  2.343333
# dtype: float64

# %%
#desvio padrão
df.std(numeric_only=True)
# Out:
# customer_SeniorCitizen          0.369074
# customer_Partner                0.499782
# customer_Dependents             0.458343
# customer_tenure                24.571773
# phone_PhoneService              0.296371
# phone_MultipleLines             0.493876
# internet_OnlineSecurity         0.451897
# internet_OnlineBackup           0.475261
# internet_DeviceProtection       0.474672
# internet_TechSupport            0.453575
# internet_StreamingTV            0.486374
# internet_StreamingMovies        0.487214
# account_PaperlessBilling        0.491265
# account_Charges.Monthly        30.129572
# account_Charges.Total        2268.632997
# Contas_Diarias                  1.004319
# dtype: float64

# %%
#Assimetria
df.skew(numeric_only=True)
# Out:
# customer_SeniorCitizen       1.828574
# customer_Partner             0.063620
# customer_Dependents          0.872408
# customer_tenure              0.239523
# phone_PhoneService          -2.718357
# phone_MultipleLines          0.316889
# internet_OnlineSecurity      0.947600
# internet_OnlineBackup        0.654257
# internet_DeviceProtection    0.662608
# internet_TechSupport         0.928315
# internet_StreamingTV         0.477429
# internet_StreamingMovies     0.461915
# account_PaperlessBilling    -0.379654
# account_Charges.Monthly     -0.216539
# account_Charges.Total        0.964218
# Contas_Diarias              -0.216539
# dtype: float64

# %%
#Curtose
df.kurtosis(numeric_only=True)
# Out:
# customer_SeniorCitizen       1.344052
# customer_Partner            -1.996502
# customer_Dependents         -1.239245
# customer_tenure             -1.388981
# phone_PhoneService           5.390951
# phone_MultipleLines         -1.900105
# internet_OnlineSecurity     -1.102358
# internet_OnlineBackup       -1.572380
# internet_DeviceProtection   -1.561380
# internet_TechSupport        -1.138545
# internet_StreamingTV        -1.772549
# internet_StreamingMovies    -1.787126
# account_PaperlessBilling    -1.856374
# account_Charges.Monthly     -1.261512
# account_Charges.Total       -0.230473
# Contas_Diarias              -1.261512
# dtype: float64

# %%
#Cobrança mensal por churn
df.groupby("Churn")["account_Charges.Monthly"].describe()
# Out:
#         count       mean        std    min     25%     50%      75%     max
# Churn
#         224.0  63.412277  31.388712  18.75  28.425  69.100  90.4125  115.55
# No     5174.0  61.265124  31.092648  18.25  25.100  64.425  88.4000  118.75
# Yes    1869.0  74.441332  24.666053  18.85  56.150  79.650  94.2000  118.35

# %%
#Cobrança diária por churn
df.groupby("Churn")["Contas_Diarias"].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Churn
#         224.0  2.113743  1.046290  0.625000  0.947500  2.303333  3.013750
# No     5174.0  2.042171  1.036422  0.608333  0.836667  2.147500  2.946667
# Yes    1869.0  2.481378  0.822202  0.628333  1.871667  2.655000  3.140000
#
#             max
# Churn
#        3.851667
# No     3.958333
# Yes    3.945000

# %%
#Tenure por churn
df.groupby("Churn")["customer_tenure"].describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
#         224.0  31.571429  24.998552  1.0   7.0  29.0  56.0  72.0
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
#Serviços contratados por churn
df.groupby("Churn")[["internet_OnlineSecurity",
                     "internet_OnlineBackup",
                     "phone_PhoneService"
                    ]].sum()
# Out:
#        internet_OnlineSecurity  internet_OnlineBackup  phone_PhoneService
# Churn
#                             59                     75                 199
# No                        1724                   1906                4662
# Yes                        295                    523                1699

# %%
#Correlação das variáveis numéricas
df.corr(numeric_only=True)
# Out:
#                            customer_SeniorCitizen  customer_Partner  \
# customer_SeniorCitizen                   1.000000          0.022970
# customer_Partner                         0.022970          1.000000
# customer_Dependents                     -0.212952          0.448900
# customer_tenure                          0.018187          0.377551
# phone_PhoneService                       0.010060          0.018828
# phone_MultipleLines                      0.144567          0.141187
# internet_OnlineSecurity                 -0.037953          0.141392
# internet_OnlineBackup                    0.068824          0.139523
# internet_DeviceProtection                0.060358          0.153209
# internet_TechSupport                    -0.059376          0.116228
# internet_StreamingTV                     0.103655          0.124754
# internet_StreamingMovies                 0.119374          0.115729
# account_PaperlessBilling                 0.157734         -0.011201
# account_Charges.Monthly                  0.220388          0.097122
# account_Charges.Total                    0.103499          0.316918
# Contas_Diarias                           0.220388          0.097122
#
#                            customer_Dependents  customer_tenure  \
# customer_SeniorCitizen               -0.212952         0.018187
# customer_Partner                      0.448900         0.377551
# customer_Dependents                   1.000000         0.159892
# customer_tenure                       0.159892         1.000000
# phone_PhoneService                   -0.003863         0.010205
# phone_MultipleLines                  -0.027894         0.331678
# internet_OnlineSecurity               0.083951         0.327252
# internet_OnlineBackup                 0.023686         0.361291
# internet_DeviceProtection             0.014797         0.361792
# internet_TechSupport                  0.062586         0.322139
# internet_StreamingTV                 -0.015030         0.280738
# internet_StreamingMovies             -0.040151         0.286841
# account_PaperlessBilling             -0.111752         0.007949
# account_Charges.Monthly              -0.115832         0.247982
# account_Charges.Total                 0.063960         0.825118
# Contas_Diarias                       -0.115832         0.247982
#
#                            phone_PhoneService  phone_MultipleLines  \
# customer_SeniorCitizen               0.010060             0.144567
# customer_Partner                     0.018828             0.141187
# customer_Dependents                 -0.003863            -0.027894
# customer_tenure                      0.010205             0.331678
# phone_PhoneService                   1.000000             0.280379
# phone_MultipleLines                  0.280379             1.000000
# internet_OnlineSecurity             -0.093341             0.098396
# internet_OnlineBackup               -0.052165             0.205156
# internet_DeviceProtection           -0.073033             0.202172
# internet_TechSupport                -0.097573             0.098053
# internet_StreamingTV                -0.025362             0.257405
# internet_StreamingMovies            -0.034345             0.259268
# account_PaperlessBilling             0.013624             0.163225
# account_Charges.Monthly              0.246709             0.490699
# account_Charges.Total                0.113791             0.468926
# Contas_Diarias                       0.246709             0.490699
#
#                            internet_OnlineSecurity  internet_OnlineBackup  \
# customer_SeniorCitizen                   -0.037953               0.068824
# customer_Partner                          0.141392               0.139523
# customer_Dependents                       0.083951               0.023686
# customer_tenure                           0.327252               0.361291
# phone_PhoneService                       -0.093341              -0.052165
# phone_MultipleLines                       0.098396               0.205156
# internet_OnlineSecurity                   1.000000               0.286432
# internet_OnlineBackup                     0.286432               1.000000
# internet_DeviceProtection                 0.275699               0.306665
# internet_TechSupport                      0.356113               0.292422
# internet_StreamingTV                      0.177332               0.283195
# internet_StreamingMovies                  0.189881               0.276788
# account_PaperlessBilling                 -0.001693               0.131187
# account_Charges.Monthly                   0.298307               0.442974
# account_Charges.Total                     0.413705               0.512878
# Contas_Diarias                            0.298307               0.442974
#
#                            internet_DeviceProtection  internet_TechSupport  \
# customer_SeniorCitizen                      0.060358             -0.059376
# customer_Partner                            0.153209              0.116228
# customer_Dependents                         0.014797              0.062586
# customer_tenure                             0.361792              0.322139
# phone_PhoneService                         -0.073033             -0.097573
# phone_MultipleLines                         0.202172              0.098053
# internet_OnlineSecurity                     0.275699              0.356113
# internet_OnlineBackup                       0.306665              0.292422
# internet_DeviceProtection                   1.000000              0.332267
# internet_TechSupport                        0.332267              1.000000
# internet_StreamingTV                        0.394421              0.278376
# internet_StreamingMovies                    0.402720              0.280058
# account_PaperlessBilling                    0.105211              0.037581
# account_Charges.Monthly                     0.483590              0.338429
# account_Charges.Total                       0.524712              0.431987
# Contas_Diarias                              0.483590              0.338429
#
#                            internet_StreamingTV  internet_StreamingMovies  \
# customer_SeniorCitizen                 0.103655                  0.119374
# customer_Partner                       0.124754                  0.115729
# customer_Dependents                   -0.015030                 -0.040151
# customer_tenure                        0.280738                  0.286841
# phone_PhoneService                    -0.025362                 -0.034345
# phone_MultipleLines                    0.257405                  0.259268
# internet_OnlineSecurity                0.177332                  0.189881
# internet_OnlineBackup                  0.283195                  0.276788
# internet_DeviceProtection              0.394421                  0.402720
# internet_TechSupport                   0.278376                  0.280058
# internet_StreamingTV                   1.000000                  0.531336
# internet_StreamingMovies               0.531336                  1.000000
# account_PaperlessBilling               0.224574                  0.212443
# account_Charges.Monthly                0.628874                  0.628184
# account_Charges.Total                  0.516900                  0.521245
# Contas_Diarias                         0.628874                  0.628184
#
#                            account_PaperlessBilling  account_Charges.Monthly  \
# customer_SeniorCitizen                     0.157734                 0.220388
# customer_Partner                          -0.011201                 0.097122
# customer_Dependents                       -0.111752                -0.115832
# customer_tenure                            0.007949                 0.247982
# phone_PhoneService                         0.013624                 0.246709
# phone_MultipleLines                        0.163225                 0.490699
# internet_OnlineSecurity                   -0.001693                 0.298307
# internet_OnlineBackup                      0.131187                 0.442974
# internet_DeviceProtection                  0.105211                 0.483590
# internet_TechSupport                       0.037581                 0.338429
# internet_StreamingTV                       0.224574                 0.628874
# internet_StreamingMovies                   0.212443                 0.628184
# account_PaperlessBilling                   1.000000                 0.353714
# account_Charges.Monthly                    0.353714                 1.000000
# account_Charges.Total                      0.159303                 0.652109
# Contas_Diarias                             0.353714                 1.000000
#
#                            account_Charges.Total  Contas_Diarias
# customer_SeniorCitizen                  0.103499        0.220388
# customer_Partner                        0.316918        0.097122
# customer_Dependents                     0.063960       -0.115832
# customer_tenure                         0.825118        0.247982
# phone_PhoneService                      0.113791        0.246709
# phone_MultipleLines                     0.468926        0.490699
# internet_OnlineSecurity                 0.413705        0.298307
# internet_OnlineBackup                   0.512878        0.442974
# internet_DeviceProtection               0.524712        0.483590
# internet_TechSupport                    0.431987        0.338429
# internet_StreamingTV                    0.516900        0.628874
# internet_StreamingMovies                0.521245        0.628184
# account_PaperlessBilling                0.159303        0.353714
# account_Charges.Monthly                 0.652109        1.000000
# account_Charges.Total                   1.000000        0.652109
# Contas_Diarias                          0.652109        1.000000

# %%
df.describe(include='all')
# Out:
#         customerID Churn customer_gender  customer_SeniorCitizen  \
# count         7267  7267            7267             7267.000000
# unique        7267     3               2                     NaN
# top     9995-HOTOH    No            Male                     NaN
# freq             1  5174            3675                     NaN
# mean           NaN   NaN             NaN                0.162653
# std            NaN   NaN             NaN                0.369074
# min            NaN   NaN             NaN                0.000000
# 25%            NaN   NaN             NaN                0.000000
# 50%            NaN   NaN             NaN                0.000000
# 75%            NaN   NaN             NaN                0.000000
# max            NaN   NaN             NaN                1.000000
#
#         customer_Partner  customer_Dependents  customer_tenure  \
# count        7267.000000          7267.000000      7267.000000
# unique               NaN                  NaN              NaN
# top                  NaN                  NaN              NaN
# freq                 NaN                  NaN              NaN
# mean            0.484106             0.300124        32.346498
# std             0.499782             0.458343        24.571773
# min             0.000000             0.000000         0.000000
# 25%             0.000000             0.000000         9.000000
# 50%             0.000000             0.000000        29.000000
# 75%             1.000000             1.000000        55.000000
# max             1.000000             1.000000        72.000000
#
#         phone_PhoneService  phone_MultipleLines internet_InternetService  ...  \
# count          7267.000000          7267.000000                     7267  ...
# unique                 NaN                  NaN                        3  ...
# top                    NaN                  NaN              Fiber optic  ...
# freq                   NaN                  NaN                     3198  ...
# mean              0.902711             0.421770                      NaN  ...
# std               0.296371             0.493876                      NaN  ...
# min               0.000000             0.000000                      NaN  ...
# 25%               1.000000             0.000000                      NaN  ...
# 50%               1.000000             0.000000                      NaN  ...
# 75%               1.000000             1.000000                      NaN  ...
# max               1.000000             1.000000                      NaN  ...
#
#         internet_DeviceProtection  internet_TechSupport  internet_StreamingTV  \
# count                 7267.000000           7267.000000           7267.000000
# unique                        NaN                   NaN                   NaN
# top                           NaN                   NaN                   NaN
# freq                          NaN                   NaN                   NaN
# mean                     0.342782              0.289528              0.383927
# std                      0.474672              0.453575              0.486374
# min                      0.000000              0.000000              0.000000
# 25%                      0.000000              0.000000              0.000000
# 50%                      0.000000              0.000000              0.000000
# 75%                      1.000000              1.000000              1.000000
# max                      1.000000              1.000000              1.000000
#
#         internet_StreamingMovies  account_Contract  account_PaperlessBilling  \
# count                7267.000000              7267               7267.000000
# unique                       NaN                 3                       NaN
# top                          NaN    Month-to-month                       NaN
# freq                         NaN              4005                       NaN
# mean                    0.387505               NaN                  0.593230
# std                     0.487214               NaN                  0.491265
# min                     0.000000               NaN                  0.000000
# 25%                     0.000000               NaN                  0.000000
# 50%                     0.000000               NaN                  1.000000
# 75%                     1.000000               NaN                  1.000000
# max                     1.000000               NaN                  1.000000
#
#        account_PaymentMethod  account_Charges.Monthly account_Charges.Total  \
# count                   7267              7267.000000           7256.000000
# unique                     4                      NaN                   NaN
# top         Electronic check                      NaN                   NaN
# freq                    2445                      NaN                   NaN
# mean                     NaN                64.720098           2280.634213
# std                      NaN                30.129572           2268.632997
# min                      NaN                18.250000             18.800000
# 25%                      NaN                35.425000            400.225000
# 50%                      NaN                70.300000           1391.000000
# 75%                      NaN                89.875000           3785.300000
# max                      NaN               118.750000           8684.800000
#
#         Contas_Diarias
# count      7267.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean          2.157337
# std           1.004319
# min           0.608333
# 25%           1.180833
# 50%           2.343333
# 75%           2.995833
# max           3.958333
#
# [11 rows x 22 columns]

# %%
#Contagem de clientes por churn
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
#Gráfico de Barras – Distribuição de Churn
import matplotlib.pyplot as plt

counts = df["Churn"].value_counts().sort_index()

plt.figure(figsize=(6,4))
plt.bar(counts.index.astype(str), counts.values)
plt.xlabel("Churn (0 = Permaneceu, 1 = Saiu)")
plt.ylabel("Quantidade de Clientes")
plt.title("Distribuição de Evasão de Clientes (Churn)")
plt.tight_layout()
plt.show()

# %%
df["Churn"] = df["Churn"].replace("", pd.NA).map({"No":0, "Yes":1}).astype('Int64')

# %%
#Gráfico de Pizza – Proporção de Churn
import matplotlib.pyplot as plt


counts = df["Churn"].value_counts(dropna=False).sort_index()


print("Counts:\n", counts)
print("Índices:", counts.index.tolist())


mapping = {
    0: "Permaneceu (0)",
    1: "Saiu (1)",
    "No": "Permaneceu (No)",
    "Yes": "Saiu (Yes)",
    "": "Vazio",
    None: "NaN"
}
labels = [mapping.get(idx, str(idx)) for idx in counts.index]

# 4) plot seguro do gráfico pizza
plt.figure(figsize=(6,6))
plt.pie(counts.values, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Proporção de Clientes por Churn")
plt.axis('equal')
plt.show()
# Out:
# Counts:
#  Churn
# 0       5174
# 1       1869
# <NA>     224
# Name: count, dtype: Int64
# Índices: [0, 1, <NA>]

# %%
#Função para gerar gráficos automaticamente
import matplotlib.pyplot as plt
import seaborn as sns

def churn_por_categoria(df, coluna):
    plt.figure(figsize=(8,4))
    sns.countplot(data=df, x=coluna, hue="Churn")
    plt.title(f"Churn por {coluna}")
    plt.xlabel(coluna)
    plt.ylabel("Contagem")
    plt.xticks(rotation=45)
    plt.legend(title="Churn", labels=["0 = Permaneceu", "1 = Saiu"])
    plt.tight_layout()
    plt.show()

# %%
#Gerar gráficos para todas as categorias principais
categorias = [
    "customer_gender",
    "customer_Partner",
    "customer_Dependents",
    "phone_PhoneService",
    "phone_MultipleLines",
    "internet_InternetService",
    "internet_OnlineSecurity",
    "internet_OnlineBackup",
    "internet_DeviceProtection",
    "internet_TechSupport",
    "internet_StreamingTV",
    "internet_StreamingMovies",
    "account_Contract",
    "account_PaperlessBilling",
    "account_PaymentMethod"
]

for coluna in categorias:
    churn_por_categoria(df, coluna)

# %%
# Converter Total Charges para numérico
df["account_Charges.Total"] = pd.to_numeric(df["account_Charges.Total"], errors="coerce")

# Verificar se deu certo
print(df["account_Charges.Total"].dtypes)
print(df["account_Charges.Total"].describe())
# Out:
# float64
# count    7256.000000
# mean     2280.634213
# std      2268.632997
# min        18.800000
# 25%       400.225000
# 50%      1391.000000
# 75%      3785.300000
# max      8684.800000
# Name: account_Charges.Total, dtype: float64

# %%
#Boxplot – Distribuição por Churn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
sns.histplot(
    data=df,
    x="account_Charges.Total",
    hue="Churn",
    kde=True,
    element="step",
    bins=50
)
plt.title("Distribuição de Total Charges por Churn")
plt.xlabel("Total Charges")
plt.ylabel("Contagem")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(data=df, x="Churn", y="account_Charges.Total")
plt.title("Boxplot de Total Charges por Churn")
plt.xlabel("Churn (0 = Permaneceu, 1 = Saiu)")
plt.ylabel("Total Charges")
plt.tight_layout()
plt.show()

# %%
#Histogramas (ou KDE) – Comparando Curvas
def hist_churn(df, coluna):
    plt.figure(figsize=(7,4))
    sns.histplot(data=df, x=coluna, hue="Churn", kde=True, element="step")
    plt.title(f"Distribuição de {coluna} por Churn")
    plt.xlabel(coluna)
    plt.ylabel("Contagem")
    plt.tight_layout()
    plt.show()

hist_churn(df, "customer_tenure")
hist_churn(df, "account_Charges.Monthly")
hist_churn(df, "account_Charges.Total")
hist_churn(df, "Contas_Diarias")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def boxplot_churn(df, coluna):
    plt.figure(figsize=(7,4))
    sns.boxplot(data=df, x="Churn", y=coluna)
    plt.title(f"Distribuição de {coluna} por Churn")
    plt.xlabel("Churn (0 = Permaneceu, 1 = Saiu)")
    plt.ylabel(coluna)
    plt.tight_layout()
    plt.show()

boxplot_churn(df, "customer_tenure")
boxplot_churn(df, "account_Charges.Monthly")
boxplot_churn(df, "account_Charges.Total")
boxplot_churn(df, "Contas_Diarias")

# %%
#Comparação direta das médias
df.groupby("Churn")[["customer_tenure",
                     "account_Charges.Monthly",
                     "account_Charges.Total",
                     "Contas_Diarias"]].mean()
# Out:
#        customer_tenure  account_Charges.Monthly  account_Charges.Total  \
# Churn
# 0            37.569965                61.265124            2555.344141
# 1            17.979133                74.441332            1531.796094
#
#        Contas_Diarias
# Churn
# 0            2.042171
# 1            2.481378

# %%
df["account_Charges.Total"].unique()[:20]
# Out:
# array([ 593.3 ,  542.4 ,  280.85, 1237.85,  267.4 ,  571.45, 7904.25,
#        5377.8 ,  340.35, 5957.9 , 2460.55, 8456.75,  351.5 , 7261.25,
#        2560.1 , 6849.4 , 1993.2 ,   72.1 , 2791.5 ,   25.1 ])

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# #RELATÓRIO FINAL – Análise de Evasão de Clientes (Churn) – TelecomX
# 1. Introdução
#
# Este relatório apresenta uma análise aprofundada sobre o fenômeno de evasão de clientes (churn) na empresa TelecomX, uma provedora de serviços de telecomunicações que enfrenta um aumento significativo no número de cancelamentos.
#
# O principal objetivo deste estudo é:
#
# - Identificar padrões de comportamento associados ao churn;
#
# - Compreender quais perfis de clientes cancelam mais;
#
# - Detectar serviços e condições contratuais que contribuem para o cancelamento;
#
# - Fornecer insights estratégicos para reduzir a evasão.
#
# A análise é dividida em quatro etapas principais: extração, transformação, análise exploratória e relatório final.
#
# ---
#
# 2. Limpeza e Tratamento de Dados
#
# Após a importação do dataset TelecomX_Data.json, foram realizadas diversas etapas de preparação dos dados, fundamentais para garantir a qualidade das análises:
#
# **2.1 Padronização das Variáveis**
#
# Conversão da variável Churn para valores binários:
#
# "No" → 0
#
# "Yes" → 1
#
# Padronização de colunas categóricas com valores inconsistentes, como:
#
# "No internet service"
#
# "No phone service" :
# Essas categorias foram normalizadas para “No”.
#
# **2.2 Conversão de Tipos**
#
# Colunas numéricas como:
#
# account_Charges.Monthly
#
# account_Charges.Total
# foram convertidas para o tipo numérico (float), corrigindo valores inválidos e strings.
#
# **2.3 Criação de Novas Variáveis**
#
# Criada a coluna Contas_Diarias, calculada como:
#
# Contas_diarias = Cobrança Mensal dividio por 30
#
# **2.4 Tratamento de Valores Ausentes**
#
# Tratamento de NaN em colunas numéricas por meio de conversões e coerção (errors="coerce").
#
# Verificação de inconsistências em variáveis categóricas com value_counts() e unique().
#
# ---
#
# 3. Análise Exploratória de Dados (EDA)
#
# A Análise Exploratória foi dividida em três eixos:
#
# **3.1 Distribuição Geral de Churn**
#
# Foram gerados gráficos de barras e pizza para visualizar a proporção de clientes que cancelaram (1) e os que permaneceram (0).
#
# Principais observações:
#
# A base apresenta um nível significativo de churn.
#
# Há desbalanceamento entre as classes, típico de bases de telecom.
#
# **3.2 Churn por Variáveis Categóricas**
#
# Gráficos gerados com countplot() mostraram padrões importantes:
#
# 🔸 Tipo de Contrato (account_Contract)
#
# Clientes com Month-to-month apresentam o maior churn.
#
# Fidelizações One-year ou Two-year têm churn muito menor.
#
# 🔸 Serviços de Internet
#
# Clientes com Fiber optic (Fibra óptica) têm churn significativamente maior.
#
# Clientes com DSL apresentam churn menor.
#
# 🔸 Segurança e Suporte Técnico
#
# Clientes sem:
#
# OnlineSecurity
#
# TechSupport
#
# DeviceProtection
# são os que mais cancelam.
#
# 🔸 Método de Pagamento
#
# O método Electronic Check concentra grande parte dos churners.
#
# **3.3 Churn por Variáveis Numéricas**
#
# Gráficos de histogramas, KDE e boxplots foram gerados para:
#
# 🔸 Tempo de Permanência (tenure):
#
# Clientes churn tendem a ter menos tempo de casa.
#
# O boxplot indica permanência média muito menor entre canceladores.
#
# 🔸 Cobrança Mensal (Monthly Charges):
#
# Churners pagam mensalidades mais altas em média e sugerem sensibilidade ao preço.
#
# 🔸 Total Gasto (Total Charges):
#
# Clientes churn apresentam valores baixos, indicando que muitos cancelam cedo.
#
# 🔸 Contas Diárias
#
# Clientes churn apresentam valores ligeiramente maiores, reforçando a hipótese de desconforto com preço.
#
# 4. Conclusões e Insights
#
# A partir das análises realizadas, é possível concluir que o churn da TelecomX está fortemente associado a:
#
# ✔ Períodos curtos de permanência:
#
# Clientes recém-contratados são os mais propensos a cancelar.
#
# ✔ Planos Mensais (Month-to-month):
#
# Clientes sem fidelização cancelam com frequência elevada.
#
# ✔ Cobranças mensais elevadas:
#
# Alta sensibilidade ao preço é observada nos churners.
#
# ✔ Falta de serviços adicionais de proteção:
#
# Churn é maior entre clientes sem segurança online, backup, suporte técnico ou proteção de equipamento.
#
# ✔ Uso de pagamento por Electronic Check:
#
# Clientes desse método apresentam comportamento bem mais volátil.
#
# ✔ Serviço de Internet Fibra Óptica:
#
# Embora mais rápido, apresenta maior evasão — possivelmente por custo ou instabilidade.
#
# Esses padrões são consistentes com o comportamento real de churn no setor de telecomunicações.
#
# 5. Recomendações
#
# Com base nos insights encontrados, recomenda-se:
#
# * Criar planos de retenção para clientes novos (primeiros 3 meses)
#
# Oferecer benefícios ou acompanhamento ativo reduz o churn inicial.
#
# * Descontos ou incentivos em planos de Fibra Óptica
#
# Clientes deste serviço demonstram maior probabilidade de cancelamento.
#
# * Oferecer upgrades gratuitos de segurança
#
# Como OnlineSecurity e TechSupport para reduzir o risco percebido.
#
# * Tornar os planos mensais mais atrativos
#
# Reduzir prazos de fidelização ou oferecer vantagens exclusivas.
#
# * Incentivar migração de método de pagamento
#
# Reduzir Electronic Check e incentivar pagamentos automáticos.
#
# * Implementar modelo preditivo de churn
#
# Com os dados preparados, é possível treinar modelos para prever quem está prestes a cancelar e fazer com que a Telecom X cresca novamente!
